# %% [markdown]
# # やること
#
# 音の変換
# 1. 子音または母音の認識
# 2. 分解
# 3. 変換

# %%
import pandas as pd
import openpyxl
import numpy as np
import copy

# %%
basepath="/Users/kazuki/Documents/Study/test/data/ryukyu4/{}"

rfcnsts=basepath.format("parameter/consonants-list.csv")
rfvws  =basepath.format("parameter/vowels-list.csv")

rforg  =basepath.format("第2調査票/01_第2調査票_奄美/201_調査票_第２奄美国直.xlsx")

# %%
cnstsDf=pd.read_csv(rfcnsts,sep="\t",index_col=0)
vwsDf  =pd.read_csv(rfvws  ,sep="\t",index_col=0)

# %%
cnstsDf
# Out:
#     IPA  代替文字  位置  方法  口蓋・円唇  喉頭化  声帯振動
# 1     p     p   1   1      0    0     1
# 2    pʻ    ph   1   1      0    1     1
# 3    pʼ    px   1   1      0    2     1
# 4    pj    pj   1   1      2    0     1
# 5   pjʻ   pjh   1   1      2    1     1
# 6   pjʼ   pjx   1   1      2    2     1
# 7     b     b   1   1      0    0     0
# 8    bj    bj   1   1      2    0     0
# 9     ɸ    hw   1   3      0    0     1
# 10    ʔ     ?  11   1      0    1     0
# 11    ʼ     !  11   7      0    0     0
# 12    h     h  11   2      0    0     1
# 13    ɦ    h!  11   2      0    0     0
# 14    m     m   1   4      0    0     0
# 15   ʼm    !m   1   4      0    1     0
# 16   ʔm    ?m   1   4      0    2     0
# 17   mj    mj   1   4      2    0     0
# 18  ʼmj   !mj   1   4      2    1     0
# 19  ʔmj   ?mj   1   4      2    2     0
# 20    f     f   2   3      0    0     1
# 21    v     v   2   3      0    0     1
# 22    t     t   4   1      0    0     1
# 23   t̒    th   4   1      0    1     1
# 24   t̓    tx   4   1      0    2     1
# 25   tɵ   ts3   3   2      0    0     0
# 26   tj    tj   4   1      2    0     1
# 27  tjʻ   tjh   4   1      2    1     1
# 28  tjʼ   tjx   4   1      2    2     1
# 29    d     d   4   1      0    0     0
# 30    ʦ    ts   4   2      0    0     1
# ..  ...   ...  ..  ..    ...  ...   ...
# 51   ʔr    ?r   4   5      0    1     0
# 52   rj    rj   4   5      2    0     0
# 53    ç    hj   7   3      0    0     1
# 54    k     k   8   1      0    0     1
# 55   k̒    kh   8   1      0    1     1
# 56   k̓    kx   8   1      0    2     1
# 57   kj    kj   8   1      2    0     1
# 58  kjʻ   kjh   8   1      2    1     1
# 59  kjʼ   kjx   8   1      2    2     1
# 60   kw    kw   8   1      4    0     1
# 61  kwʻ   kwh   8   1      4    1     1
# 62  kwʼ   kwx   8   1      4    2     1
# 63    g     g   8   1      0    0     0
# 64   gj    gj   8   1      2    0     0
# 65   gw    gw   8   1      4    0     0
# 66    ŋ    ng   8   1      1    0     0
# 67    j     j   7   7      0    0     0
# 68   ʔj    ?j   7   7      0    1     0
# 69   ʼj    !j   7   7      0    2     0
# 70    w     w   1   7      0    0     0
# 71   ʔw    ?w   1   7      0    1     0
# 72   ʼw    !w   1   7      0    2     0
# 73    N    n2  12   4      0    0     0
# 74   ʔN   ?n2  12   4      0    1     0
# 75   ʼN   !n2  12   4      0    2     0
# 76   N:   n2:  13   4      0    0     0
# 77  ʔN:  ?n2:  14   4      0    0     0
# 78   iN   in2  15   4      0    0     0
# 79  ʔiN  ?in2  16   4      0    0     0
# 80    Q     q  12   1      0    0     0
#
# [80 rows x 7 columns]

# %%
print(cnstsDf.index)
print(cnstsDf.columns)

# %%
vwsDf

# %%
orgDf=pd.read_excel(rforg,header=0)

# %%
orgDf

# %%
oninDf=orgDf.loc[ :, ["音韻表記１","表記２"]]

# %%
len(oninDf)
# Out:
# 346

# %%
oninDf

# %% [markdown]
# 音の認識をどう行う？

# %%
splitOnin=[]
for i in oninDf.index:
    bunkais=[]
    onin=oninDf.iat[i,0]
    print("{}番目の音韻  >  {}".format(i,onin))

    if onin=="NR" or i==19 or ("/" in onin) or (" " in onin):
        splitOnin.append(["-1"])
        continue
#     if onin=="k̒at̒ïmuŋ":
#         print("k̓" in onin)
#         print("k̒" in onin)
#     if "k̒" in onin:
#         print("変えたい")
#         tmpOn=list(onin)
# #         onin.replace("k̒","k̓")
#         tmpOn[onin.index("k̒"):len("k̒")]="k̓"
#         onin="".join(tmpOn)
#         print(onin)
#         print("k̓" in onin)
    new_onin=onin
    
    splitflag=True
    counter=1
    while splitflag:
        print("{}回目".format(counter))
        new_cnsts=[]
        new_vws =[]
        for ci,cnst in enumerate(cnstsDf.iloc[:,0].values):
            if cnst in new_onin:
                new_cnsts.append(cnst)
#                 print("{} 子音{}".format(ci,cnst))
        for vi,vw in enumerate(vwsDf.iloc[:,0].values):
            if vw in new_onin:
                new_vws.append(vw)
#                 print("{} 母音{}".format(vi,vw))

        print("子音   {}".format(new_cnsts))
        print("母音   {}".format(new_vws))

        new_cnstsInd=[new_onin.index(cnst) for cnst in new_cnsts]
        new_vwsInd =[new_onin.index(vw) for vw  in new_vws]
        print(new_cnstsInd)
        print(new_vwsInd)
        if len(new_cnsts)==0:
            new_cnstsInd=[-1]
        if len(new_vws)==0:
            new_vwsInd=[-1]
        if min(new_cnstsInd)==0 and min(new_vwsInd)==0:
            if len(new_cnsts[new_cnstsInd.index(0)]) > len(new_vws[new_vwsInd.index(0)]):
                bunkai=new_cnsts[new_cnstsInd.index(0)]
            else:
                bunkai=new_vws[new_vwsInd.index(0)]
        elif min(new_cnstsInd)==0:
            if new_cnstsInd.count(0) > 1:
                zeroInd=[cnst for cnst,cnstInd in zip(new_cnsts,new_cnstsInd) if cnstInd == 0]
                print("子音の変換{}".format(zeroInd))
                symsize=[len(zero) for zero in zeroInd]
                symind=symsize.index(max(symsize))
                bunkai=zeroInd[symind]
#                 if ("k̓" in new_cnsts) and bunkai=="k":
#                     bunkai="k̓"
            else:
                 bunkai=new_cnsts[new_cnstsInd.index(0)]
        else:
            if new_vwsInd.count(0) > 1:
                zeroInd=[vw for vw,vwInd in zip(new_vws,new_vwsInd) if vwInd == 0]
                symsize=[len(zero) for zero in zeroInd]
                symind=symsize.index(max(symsize))
                bunkai=zeroInd[symind]
            else:
                 bunkai=new_vws[new_vwsInd.index(0)]
        print(bunkai)

        bunkais.append(new_onin[0:len(bunkai)])
        new_onin=new_onin[len(bunkai):]
        print("区切り>{}   残り>{}   文字数>{}".format(bunkais,new_onin,len(new_onin)))
        if len(new_onin) == 0:
            splitflag=False
        counter+=1
    splitOnin.append(bunkais)
# Out:
# 0番目の音韻  >  mïzï
# 1回目
# 子音   ['m', 'z']
# 母音   ['ï']
# [0, 2]
# [1]
# m
# 区切り>['m']   残り>ïzï   文字数>3
# 2回目
# 子音   ['z']
# 母音   ['ï']
# [1]
# [0]
# ï
# 区切り>['m', 'ï']   残り>zï   文字数>2
# 3回目
# 子音   ['z']
# 母音   ['ï']
# [0]
# [1]
# z
# 区切り>['m', 'ï', 'z']   残り>ï   文字数>1
# 4回目
# 子音   []
# 母音   ['ï']
# []
# [0]
# ï
# 区切り>['m', 'ï', 'z', 'ï']   残り>   文字数>0
# 1番目の音韻  >  ju
# 1回目
# 子音   ['j']
# 母音   ['u']
# [0]
# [1]
# j
# 区切り>['j']   残り>u   文字数>1
# 2回目
# 子音   []
# 母音   ['u']
# []
# [0]
# u
# 区切り>['j', 'u']   残り>   文字数>0
# 2番目の音韻  >  ʔatzïk̓ë
# 1回目
# 子音   ['ʔ', 't', 'z', 'k', 'k̓']
# 母音   ['ï', 'ë', 'a']
# [0, 2, 3, 5, 5]
# [4, 7, 1]
# ʔ
# 区切り>['ʔ']   残り>atzïk̓ë   文字数>7
# 2回目
# 子音   ['t', 'z', 'k', 'k̓']
# 母音   ['ï', 'ë', 'a']
# [1, 2, 4, 4]
# [3, 6, 0]
# a
# 区切り>['ʔ', 'a']   残り>tzïk̓ë   文字数>6
# 3回目
# 子音   ['t', 'z', 'k', 'k̓']
# 母音   ['ï', 'ë']
# [0, 1, 3, 3]
# [2, 5]
# t
# 区切り>['ʔ', 'a', 't']   残り>zïk̓ë   文字数>5
# 4回目
# 子音   ['z', 'k', 'k̓']
# 母音   ['ï', 'ë']
# [0, 2, 2]
# [1, 4]
# z
# 区切り>['ʔ', 'a', 't', 'z']   残り>ïk̓ë   文字数>4
# 5回目
# 子音   ['k', 'k̓']
# 母音   ['ï', 'ë']
# [1, 1]
# [0, 3]
# ï
# 区切り>['ʔ', 'a', 't', 'z', 'ï']   残り>k̓ë   文字数>3
# 6回目
# 子音   ['k', 'k̓']
# 母音   ['ë']
# [0, 0]
# [2]
# 子音の変換['k', 'k̓']
# k̓
# 区切り>['ʔ', 'a', 't', 'z', 'ï', 'k̓']   残り>ë   文字数>1
# 7回目
# 子音   []
# 母音   ['ë']
# []
# [0]
# ë
# 区切り>['ʔ', 'a', 't', 'z', 'ï', 'k̓', 'ë']   残り>   文字数>0
# 3番目の音韻  >  ʧa
# 1回目
# 子音   ['ʧ']
# 母音   ['a']
# [0]
# [1]
# ʧ
# 区切り>['ʧ']   残り>a   文字数>1
# 2回目
# 子音   []
# 母音   ['a']
# []
# [0]
# a
# 区切り>['ʧ', 'a']   残り>   文字数>0
# 4番目の音韻  >  NR
# 5番目の音韻  >  hammë
# 1回目
# 子音   ['h', 'm']
# 母音   ['ë', 'a']
# [0, 2]
# [4, 1]
# h
# 区切り>['h']   残り>ammë   文字数>4
# 2回目
# 子音   ['m']
# 母音   ['ë', 'a']
# [1]
# [3, 0]
# a
# 区切り>['h', 'a']   残り>mmë   文字数>3
# 3回目
# 子音   ['m']
# 母音   ['ë']
# [0]
# [2]
# m
# 区切り>['h', 'a', 'm']   残り>më   文字数>2
# 4回目
# 子音   ['m']
# 母音   ['ë']
# [0]
# [1]
# m
# 区切り>['h', 'a', 'm', 'm']   残り>ë   文字数>1
# 5回目
# 子音   []
# 母音   ['ë']
# []
# [0]
# ë
# 区切り>['h', 'a', 'm', 'm', 'ë']   残り>   文字数>0
# 6番目の音韻  >  miʃi
# 1回目
# 子音   ['m', 'ʃ']
# 母音   ['i']
# [0, 2]
# [1]
# m
# 区切り>['m']   残り>iʃi   文字数>3
# 2回目
# 子音   ['ʃ']
# 母音   ['i']
# [1]
# [0]
# i
# 区切り>['m', 'i']   残り>ʃi   文字数>2
# 3回目
# 子音   ['ʃ']
# 母音   ['i']
# [0]
# [1]
# ʃ
# 区切り>['m', 'i', 'ʃ']   残り>i   文字数>1
# 4回目
# 子音   []
# 母音   ['i']
# []
# [0]
# i
# 区切り>['m', 'i', 'ʃ', 'i']   残り>   文字数>0
# 7番目の音韻  >  ʃiru
# 1回目
# 子音   ['ʃ', 'r']
# 母音   ['i', 'u']
# [0, 2]
# [1, 3]
# ʃ
# 区切り>['ʃ']   残り>iru   文字数>3
# 2回目
# 子音   ['r']
# 母音   ['i', 'u']
# [1]
# [0, 2]
# i
# 区切り>['ʃ', 'i']   残り>ru   文字数>2
# 3回目
# 子音   ['r']
# 母音   ['u']
# [0]
# [1]
# r
# 区切り>['ʃ', 'i', 'r']   残り>u   文字数>1
# 4回目
# 子音   []
# 母音   ['u']
# []
# [0]
# u
# 区切り>['ʃ', 'i', 'r', 'u']   残り>   文字数>0
# 8番目の音韻  >  k̒at̒ïmuŋ
# 1回目
# 子音   ['m', 't', 't̒', 'k', 'k̒', 'ŋ']
# 母音   ['ï', 'a', 'u']
# [6, 3, 3, 0, 0, 8]
# [5, 2, 7]
# 子音の変換['k', 'k̒']
# t
# 区切り>['k']   残り>̒at̒ïmuŋ   文字数>8
# 2回目
# 子音   ['m', 't', 't̒', 'ŋ']
# 母音   ['ï', 'a', 'u']
# [5, 2, 2, 7]
# [4, 1, 6]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-27f4d18c3ad1> in <module>()
#      70                 bunkai=new_vws[symind]
#      71             else:
# ---> 72                  bunkai=new_vws[new_vwsInd.index(0)]
#      73         print(bunkai)
#      74
#
# ValueError: 0 is not in list

# %% [raw]
# print(oninDf.iat[18,0])

# %%
"k̒" in "k̒at̒ïmuŋ"

# %%
print(len("k̒"))

# %%
"g" in oninDf.iat[35,0]
# Out:
# True

# %%
cnstsDf.iloc[:,0].values
# Out:
# array(['p', 'pʻ', 'pʼ', 'pj', 'pjʻ', 'pjʼ', 'b', 'bj', 'Φ', 'ʔ', 'ʼ', 'h',
#        'ɦ', 'm', 'ʼm', 'ʔm', 'mj', 'ʼmj', 'ʔmj', 'f', 'v', 't', 't̒',
#        'tʼ', 'tɵ', 'tj', 'tjʻ', 'tjʼ', 'd', 'ʦ', 'ʦʻ', 'ʦʼ', 'ʧ', 'ʧʻ',
#        'ʧʼ', 'ʣ', 'ʣ', 'ʤ', 's', 's', 'ʃ', 'z', 'ʒ', 'n', 'ʼn', 'ʔn',
#        'nj', 'nj', 'ʔnj', 'r', 'ʔr', 'rj', 'ç', 'k', 'k̒', 'k̓', 'kj',
#        'kjʻ', 'kjʼ', 'kw', 'kwʻ', 'kwʼ', 'ɡ', 'ɡj', 'gw', 'ŋ', 'j', 'ʔj',
#        'ʼj', 'w', 'ʔw', 'ʼw', 'N', 'ʔN', 'ʼN', 'N:', 'ʔN:', 'iN', 'ʔiN',
#        'Q'], dtype=object)

# %%
cnstsDf.iat[62,0] == 'g'
# Out:
# False

# %%
"ɡ" == "g"
# Out:
# False

# %%
"ɸ"=="Φ"
# Out:
# False

# %%
print(len(splitOnin))
# Out:
# 346

# %%
maxlength=max([len(bunkais) for bunkais in splitOnin])

# %%
for i in range(len(splitOnin)):
    currlen=len(splitOnin[i])
    for j in range(maxlength-currlen):
        splitOnin[i].append(".")

# %%
for i in range(len(splitOnin)):
    print(splitOnin[i])
# Out:
# ['m', 'ï', 'z', 'ï', '.', '.', '.', '.', '.', '.', '.']
# ['j', 'u', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['ʔ', 'a', 't', 'z', 'ï', 'k̓', 'ë', '.', '.', '.', '.']
# ['ʧ', 'a', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['-1', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['h', 'a', 'm', 'm', 'ë', '.', '.', '.', '.', '.', '.']
# ['m', 'i', 'ʃ', 'i', '.', '.', '.', '.', '.', '.', '.']
# ['ʃ', 'i', 'r', 'u', '.', '.', '.', '.', '.', '.', '.']
# ['k̒', 'a', 't̒', 'ï', 'm', 'u', 'ŋ', '.', '.', '.', '.']
# ['k', 'ai', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['ʔ', 'u', 'ʃ', 'u', '.', '.', '.', '.', '.', '.', '.']
# ['ʃ', 'oː', 'i', '.', '.', '.', '.', '.', '.', '.', '.']
# ['m', 'i', 's', 'u', '.', '.', '.', '.', '.', '.', '.']
# ['s', 'ï', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['k̒', 'o', 'ʃ', 'o', '.', '.', '.', '.', '.', '.', '.']
# ['ʔ', 'a', 'b', 'u', 'r', 'a', '.', '.', '.', '.', '.']
# ['-1', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['k̓', 'w', 'a', 'ʃ', 'i', '.', '.', '.', '.', '.', '.']
# ['k̒', 'uː', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['-1', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['ʔ', 'a', 's', 'a', 'b', 'a', 'ŋ', '.', '.', '.', '.']
# ['ç', 'i', 'm', 'm', 'a', 'b', 'a', 'ŋ', '.', '.', '.']
# ['j', 'uː', 'b', 'a', 'ŋ', '.', '.', '.', '.', '.', '.']
# ['-1', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['-1', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['m', 'iː', 'ʃ', 'a', 'r', 'i', '.', '.', '.', '.', '.']
# ['t̒', 'a', 'b', 'a', 'k̓', 'u', '.', '.', '.', '.', '.']
# ['k̓', 'i', 'ʃ', 'i', 'r', 'i', '.', '.', '.', '.', '.']
# ['-1', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['j', 'a', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['h', 'a', 'rj', 'a', '.', '.', '.', '.', '.', '.', '.']
# ['j', 'o', 'k', 'a', '.', '.', '.', '.', '.', '.', '.']
# ['-1', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['j', 'a', 'n', 'e', '.', '.', '.', '.', '.', '.', '.']
# ['k̒', 'a', 'w', 'a', 'r', 'a', '.', '.', '.', '.', '.']
# ['g', 'a', 'j', 'a', '.', '.', '.', '.', '.', '.', '.']
# ['t̒', 'u', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['t̒', 'ui', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['ʔ', 'a', 'm', 'a', 'd', 'ui', '.', '.', '.', '.', '.']
# ['s', 'ui', 'z', 'i', 'b', 'a', '.', '.', '.', '.', '.']
# ['j', 'uː', 'z', 'i', 'ŋ', '.', '.', '.', '.', '.', '.']
# ['-1', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['ʔw', 'aɴ', 's', 'ï', '.', '.', '.', '.', '.', '.', '.']
# ['s', 'a', 's', 'ï', 'j', 'a', '.', '.', '.', '.', '.']
# ['j', 'a', 'm', 'm', 'ë', '.', '.', '.', '.', '.', '.']
# ['t', 'z', 'u', 'k̓', 'i', 'j', 'a', 'm', 'a', '.', '.']
# ['k̒', 'a', 'ŋ', 'g', 'e', '.', '.', '.', '.', '.', '.']
# ['ʔ', 'i', 'ʃ', 'i', 'g', 'a', 'k̓', 'i', '.', '.', '.']
# ['ʤ', 'oː', 'g', 'u', 't', 'ʒ', 'i', '.', '.', '.', '.']
# ['j', 'e', 'g', 'a', 'w', 'a', '.', '.', '.', '.', '.']
# ['k', 'a', 'm', 'a', 'd', 'o', '.', '.', '.', '.', '.']
# ['m', 'ëː', 'ʃ', 'i', 'k̒', 'ï', '.', '.', '.', '.', '.']
# ['ʔm', 'a', 't', 'z', 'ï', '.', '.', '.', '.', '.', '.']
# ['-1', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['k̒', 'ï', 'b', 'u', 'ʃ', 'i', '.', '.', '.', '.', '.']
# ['ɸ', 'ë', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['s', 'ï', 's', 'ï', '.', '.', '.', '.', '.', '.', '.']
# ['-1', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['-1', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['h', 'a', 'g', 'a', 'm', 'a', '.', '.', '.', '.', '.']
# ['n', 'a', 'b', 'ï', '.', '.', '.', '.', '.', '.', '.']
# ['m', 'i', 'ʃ', 'i', 'g', 'e', '.', '.', '.', '.', '.']
# ['sa', 'k̓', 'u', 'ʃ', 'i', '.', '.', '.', '.', '.', '.']
# ['ʔ', 'i', 'b', 'b', '.', '.', '.', '.', '.', '.', '.']
# ['ɸ', 'uː', 'ʤ', 'o', 'k', 'a', '.', '.', '.', '.', '.']
# ['ʧ', 'a', 'ʤ', 'o', 'k', 'a', '.', '.', '.', '.', '.']
# ['ʧ', 'o', 'k', 'a', 'n', 't̒', 'ui', '.', '.', '.', '.']
# ['ʧ', 'a', 'ʒ', 'a', 'w', 'a', 'ŋ', '.', '.', '.', '.']
# ['m', 'aː', 'r', 'i', '.', '.', '.', '.', '.', '.', '.']
# ['m', 'i', 'ʃ', 'i', 'm', 'aː', 'r', 'i', '.', '.', '.']
# ['ʃ', 'i', 'r', 'u', 'm', 'aː', 'r', 'i', '.', '.', '.']
# ['s', 'a', 'r', 'a', '.', '.', '.', '.', '.', '.', '.']
# ['t̒', 'ï', 'm', 'u', 't', 'u', '.', '.', '.', '.', '.']
# ['s', 'a', 'ʤ', 'i', '.', '.', '.', '.', '.', '.', '.']
# ['s', 'a', 'ʤ', 'i', '.', '.', '.', '.', '.', '.', '.']
# ['ʔ', 'u', 's', 'ï', '.', '.', '.', '.', '.', '.', '.']
# ['ʔ', 'a', 'ʣ', 'ï', 'ŋ', '.', '.', '.', '.', '.', '.']
# ['t', 'z', 'ï', 't', 'z', 'ï', '.', '.', '.', '.', '.']
# ['-1', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['-1', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['-1', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['n', 'ï', 'b', 'u', '.', '.', '.', '.', '.', '.', '.']
# ['ʔw', 'a', 'n', 't̒', 'o', 'n', 'ï', '.', '.', '.', '.']
# ['-1', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['m', 'i', 'ŋ', 'g', 'a', 'm', 'ï', '.', '.', '.', '.']
# ['-1', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['-1', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['-1', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['ɸ', 'aː', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['-1', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['w', 'u', 'ŋ', 'g', 'a', '.', '.', '.', '.', '.', '.']
# ['n', 'a', 't', 'a', '.', '.', '.', '.', '.', '.', '.']
# ['k̒', 'o', 'g', 'a', 't', 'a', 'n', 'a', '.', '.', '.']
# ['k̒', 'a', 'm', 'a', '.', '.', '.', '.', '.', '.', '.']
# ['j', 'i', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['s', 'ï', 'k', 'i', '.', '.', '.', '.', '.', '.', '.']
# ['t̒', 'oː', 'g', 'ï', '.', '.', '.', '.', '.', '.', '.']
# ['k̒', 'a', 't', 'a', 'n', 'a', '.', '.', '.', '.', '.']
# ['s', 'a', 'j', 'a', '.', '.', '.', '.', '.', '.', '.']
# ['h', 'a', 's', 'a', 'ŋ', '.', '.', '.', '.', '.', '.']
# ['k̒', 'a', 'g', 'a', 'ŋ', '.', '.', '.', '.', '.', '.']
# ['k̓', 'u', 'ʃ', 'i', '.', '.', '.', '.', '.', '.', '.']
# ['s', 'a', 'b', 'a', 'k', 'i', '.', '.', '.', '.', '.']
# ['k̓', 'i', 'ɸ', 'a', '.', '.', '.', '.', '.', '.', '.']
# ['k', 'i', 'ɸ', 'a', '.', '.', '.', '.', '.', '.', '.']
# ['k̓', 'i', 'ŋ', '.', '.', '.', '.', '.', '.', '.', '.']
# ['j', 'e', 'r', 'i', '.', '.', '.', '.', '.', '.', '.']
# ['s', 'u', 'd', 'ï', '.', '.', '.', '.', '.', '.', '.']
# ['s', 'u', 's', 'u', '.', '.', '.', '.', '.', '.', '.']
# ['k̓', 'j', 'uː', 'b', 'i', '.', '.', '.', '.', '.', '.']
# ['s', 'a', 'b', 'a', '.', '.', '.', '.', '.', '.', '.']
# ['ʔ', 'a', 'ʃ', 'i', 'ʤ', 'a', '.', '.', '.', '.', '.']
# ['k', 'a', 's', 'a', '.', '.', '.', '.', '.', '.', '.']
# ['-1', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['m', 'a', 'k', 'u', 'r', 'a', '.', '.', '.', '.', '.']
# ['w', 'a', 't', 'a', '.', '.', '.', '.', '.', '.', '.']
# ['-1', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['-1', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['-1', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['h', 'a', 'r', 'i', '.', '.', '.', '.', '.', '.', '.']
# ['t̒', 'a', 'm', 'm', 'u', 'ŋ', '.', '.', '.', '.', '.']
# ['k̒', 'a', 'b', 'i', '.', '.', '.', '.', '.', '.', '.']
# ['-1', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['ʤ', 'i', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['j', 'i', 'ʣ', 'u', '.', '.', '.', '.', '.', '.', '.']
# ['h', 'a', 'k', 'u', '.', '.', '.', '.', '.', '.', '.']
# ['-1', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['b', 'oː', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['s', 'oː', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['ʔ', 'i', 't', 'a', '.', '.', '.', '.', '.', '.', '.']
# ['n', 'oː', 'g', 'i', 'r', 'i', '.', '.', '.', '.', '.']
# ['k', 'a', 'n', 'a', '.', '.', '.', '.', '.', '.', '.']
# ['k', 'u', 'g', 'i', '.', '.', '.', '.', '.', '.', '.']
# ['k', 'a', 'n', 'a', 'ʣ', 'ï', 't', 'ʒ', 'i', '.', '.']
# ['n', 'u', 'm', 'i', '.', '.', '.', '.', '.', '.', '.']
# ['ʔ', 'i', 'r', 'i', '.', '.', '.', '.', '.', '.', '.']
# ['j', 'i', 'g', 'ui', '.', '.', '.', '.', '.', '.', '.']
# ['k', 'ëː', 't', 'o', '.', '.', '.', '.', '.', '.', '.']
# ['ç', 'i', 'm', 'o', '.', '.', '.', '.', '.', '.', '.']
# ['w', 'a', 'r', 'a', 'ʣ', 'ï', 'n', 'a', '.', '.', '.']
# ['-1', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['n', 'oː', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['t', 'z', 'ï', 'n', 'a', '.', '.', '.', '.', '.', '.']
# ['d', 'ai', 'g', 'a', 'n', 'e', '.', '.', '.', '.', '.']
# ['ʔ', 'a', 'm', 'i', '.', '.', '.', '.', '.', '.', '.']
# ['g', 'u', 'm', 'i', '.', '.', '.', '.', '.', '.', '.']
# ['-1', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['t̒', 'a', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['ʔ', 'a', 'b', 'u', 'ʃ', 'i', '.', '.', '.', '.', '.']
# ['-1', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['ʔ', 'a', 't', 'a', 'r', 'i', '.', '.', '.', '.', '.']
# ['m', 'o', 'r', 'a', '.', '.', '.', '.', '.', '.', '.']
# ['-1', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['m', 'i', 't', 'ʒ', 'i', '.', '.', '.', '.', '.', '.']
# ['h', 'a', 'ʃ', 'i', '.', '.', '.', '.', '.', '.', '.']
# ['-1', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['j', 'o', 'h', 'o', '.', '.', '.', '.', '.', '.', '.']
# ['-1', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['k', 'a', 'ʤ', 'i', '.', '.', '.', '.', '.', '.', '.']
# ['ʔ', 'u', 'm', 'i', '.', '.', '.', '.', '.', '.', '.']
# ['s', 'ï', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['h', 'a', 'm', 'a', '.', '.', '.', '.', '.', '.', '.']
# ['-1', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['n', 'a', 'm', 'i', '.', '.', '.', '.', '.', '.', '.']
# ['s', 'ï', 'b', 'a', 'n', 'a', '.', '.', '.', '.', '.']
# ['ʔ', 'i', 'n', 'o', '.', '.', '.', '.', '.', '.', '.']
# ['-1', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['ʔ', 'a', 'g', 'ï', '.', '.', '.', '.', '.', '.', '.']
# ['m', 'i', 'ʧ', 'a', '.', '.', '.', '.', '.', '.', '.']
# ['d', 'u', 'r', 'u', '.', '.', '.', '.', '.', '.', '.']
# ['s', 'ï', 'n', 'a', '.', '.', '.', '.', '.', '.', '.']
# ['ʔ', 'u', 'r', 'u', '.', '.', '.', '.', '.', '.', '.']
# ['ʔ', 'i', 'ʃ', 'i', '.', '.', '.', '.', '.', '.', '.']
# ['ʔ', 'i', 'ʃ', 'i', '.', '.', '.', '.', '.', '.', '.']
# ['k', 'a', 'n', 'ï', '.', '.', '.', '.', '.', '.', '.']
# ['j', 'a', 'm', 'a', '.', '.', '.', '.', '.', '.', '.']
# ['j', 'a', 'm', 'a', '.', '.', '.', '.', '.', '.', '.']
# ['s', 'a', 'k', 'u', '.', '.', '.', '.', '.', '.', '.']
# ['w', 'u', 's', 'u', 'ʤ', 'i', '.', '.', '.', '.', '.']
# ['ç', 'i', 'r', 'a', '.', '.', '.', '.', '.', '.', '.']
# ['-1', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['-1', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['-1', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['j', 'a', 'm', 'a', '.', '.', '.', '.', '.', '.', '.']
# ['-1', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['-1', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['g', 'a', 'm', 'a', '.', '.', '.', '.', '.', '.', '.']
# ['k̒', 'o', 'm', 'o', 'r', 'i', '.', '.', '.', '.', '.']
# ['m', 'ï', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['k̒', 'o', 'm', 'o', 'r', 'i', '.', '.', '.', '.', '.']
# ['m', 'ï', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['m', 'ï', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['ʔ', 'i', 'ʣ', 'u', 'm', 'm', 'ï', 'ʣ', 'ï', '.', '.']
# ['m', 'ï', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['k̒', 'o', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['ʔ', 'oː', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['ʔ', 'oː', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['t̒', 'ï', 'ŋ', '.', '.', '.', '.', '.', '.', '.', '.']
# ['ʤ', 'i', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['t', 'e', 'd', 'a', '.', '.', '.', '.', '.', '.', '.']
# ['k̒', 'a', 't', 'a', 'j', 'a', '.', '.', '.', '.', '.']
# ['k̒', 'a', 't', 'a', 'j', 'a', '.', '.', '.', '.', '.']
# ['t', 'z', 'ï', 'k', 'i', '.', '.', '.', '.', '.', '.']
# ['m', 'i', 'kj', 'a', 'ʣ', 'ï', 'k', 'i', '.', '.', '.']
# ['-1', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['k̓', 'u', 'm', 'o', '.', '.', '.', '.', '.', '.', '.']
# ['ʔ', 'a', 'm', 'ï', '.', '.', '.', '.', '.', '.', '.']
# ['k', 'a', 'z', 'e', '.', '.', '.', '.', '.', '.', '.']
# ['-1', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['n', 'oː', 'g', 'i', '.', '.', '.', '.', '.', '.', '.']
# ['k', 'a', 'n', 'n', 'a', 'r', 'i', '.', '.', '.', '.']
# ['ç', 'i', 'ʤ', 'i', 'r', 'i', '.', '.', '.', '.', '.']
# ['ç', 'uː', 'r', 'i', '.', '.', '.', '.', '.', '.', '.']
# ['n', 'a', 'm', 'a', '.', '.', '.', '.', '.', '.', '.']
# ['k̒', 'ï', 'w', 'u', '.', '.', '.', '.', '.', '.', '.']
# ['ʔ', 'a', 'ʧ', 'a', '.', '.', '.', '.', '.', '.', '.']
# ['ʔ', 'a', 's', 'a', 't', 'e', '.', '.', '.', '.', '.']
# ['j', 'o', 'ɸ', 'a', '.', '.', '.', '.', '.', '.', '.']
# ['k̓', 'i', 'n', 'u', '.', '.', '.', '.', '.', '.', '.']
# ['w', 'u', 't', 't', 'ï', '.', '.', '.', '.', '.', '.']
# ['j', 'o', 'ɸ', 'a', 'n', 'a', 't', 'e', '.', '.', '.']
# ['t', 'ʒ', 'ui', '.', '.', '.', '.', '.', '.', '.', '.']
# ['j', 'u', 'r', 'u', '.', '.', '.', '.', '.', '.', '.']
# ['-1', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['h', 'aː', 't', 'u', 'k', 'i', '.', '.', '.', '.', '.']
# ['-1', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['m', 'a', 'ç', 'i', 'm', 'm', 'a', '.', '.', '.', '.']
# ['ç', 'i', 'm', 'm', 'a', 'm', 'm', 'a', 'd', 'o', '.']
# ['j', 'oː', 'n', 'e', 'g', 'a', 't', 'a', '.', '.', '.']
# ['-1', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['-1', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['j', 'oː', 'm', 'a', 'g', 'u', 'r', 'ï', '.', '.', '.']
# ['j', 'u', 'r', 'u', '.', '.', '.', '.', '.', '.', '.']
# ['j', 'o', 'n', 'a', 'h', 'a', '.', '.', '.', '.', '.']
# ['k̒', 'ï', 'w', 'uɴ', 's', 'ï', 'k', 'a', 'm', 'm', 'a']
# ['ʔ', 'a', 'ʧ', 'aɴ', 's', 'ï', 'k', 'a', 'm', 'm', 'a']
# ['j', 'oː', 'n', 'ï', '.', '.', '.', '.', '.', '.', '.']
# ['k̓', 'i', 'n', 'uɴ', 'j', 'u', 'r', 'u', '.', '.', '.']
# ['w', 'u', 't', 't', 'ïɴ', 'j', 'u', 'r', 'u', '.', '.']
# ['-1', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['-1', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['t', 'ʒ', 'u', 't', 'u', '.', '.', '.', '.', '.', '.']
# ['t', 'ʒ', 'u', 't', 'z', 'ï', 'k', 'i', '.', '.', '.']
# ['t', 'z', 'ï', 'k', 'i', '.', '.', '.', '.', '.', '.']
# ['t', 'ʒ', 'ui', '.', '.', '.', '.', '.', '.', '.', '.']
# ['t', 'z', 'ï', 'i', 't', 'a', 't', 'ʒ', 'i', '.', '.']
# ['t', 'z', 'ï', 'k', 'i', 'd', 'u', 'm', 'ï', '.', '.']
# ['gw', 'a', 'n', 'ʤ', 'i', 't', 'z', 'u', '.', '.', '.']
# ['k̓', 'u', 'n', 't', 'ʒ', 'i', '.', '.', '.', '.', '.']
# ['ʃ', 'oː', 'gw', 'a', 't', 'z', 'ï', 'ʣ', 'ï', 'k', 'i']
# ['n', 'i', 'gw', 'a', 't', 'z', 'ï', '.', '.', '.', '.']
# ['sa', 'ŋ', 'gw', 'a', 't', 'z', 'ï', '.', '.', '.', '.']
# ['ʃ', 'i', 'gw', 'a', 't', 'z', 'ï', '.', '.', '.', '.']
# ['g', 'o', 'gw', 'a', 't', 'z', 'ï', '.', '.', '.', '.']
# ['r', 'o', 'k', 'u', 'gw', 'a', 't', 'z', 'ï', '.', '.']
# ['ʃ', 'i', 't', 'ʒ', 'i', 'gw', 'a', 't', 'z', 'ï', '.']
# ['h', 'a', 't', 'ʒ', 'i', 'gw', 'a', 't', 'z', 'ï', '.']
# ['k', 'u', 'gw', 'a', 't', 'z', 'ï', '.', '.', '.', '.']
# ['ʤ', 'uː', 'gw', 'a', 't', 'z', 'ï', '.', '.', '.', '.']
# ['ʃ', 'i', 'm', 'o', 't', 'z', 'ï', 'k', 'i', '.', '.']
# ['ʃ', 'i', 'w', 'a', 't', 'z', 'ï', '.', '.', '.', '.']
# ['t̒', 'u', 'ʃ', 'i', '.', '.', '.', '.', '.', '.', '.']
# ['k̒', 'u', 't̒', 'u', 'ʃ', 'i', '.', '.', '.', '.', '.']
# ['j', 'a', 'nj', 'e', '.', '.', '.', '.', '.', '.', '.']
# ['m', 'i', 'ʧ', 'u', '.', '.', '.', '.', '.', '.', '.']
# ['k̒', 'u', 'ʣ', 'u', '.', '.', '.', '.', '.', '.', '.']
# ['m', 'i', 'ʧ', 'u', 'n', 'a', 't', 'e', '.', '.', '.']
# ['m', 'u', 'k', 'a', 'ʃ', 'i', '.', '.', '.', '.', '.']
# ['-1', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['n', 'a', 't', 'z', 'ï', '.', '.', '.', '.', '.', '.']
# ['h', 'a', 'r', 'u', '.', '.', '.', '.', '.', '.', '.']
# ['ʔ', 'a', 'k', 'i', '.', '.', '.', '.', '.', '.', '.']
# ['ʔ', 'a', 'k', 'i', '.', '.', '.', '.', '.', '.', '.']
# ['-1', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['m', 'i', 'k̒', 'j', 'a', '.', '.', '.', '.', '.', '.']
# ['j', 'o', 'ɸ', 'a', '.', '.', '.', '.', '.', '.', '.']
# ['ʔ', 'i', 't', 'z', 'ï', 'k', 'a', '.', '.', '.', '.']
# ['m', 'ui', 'k', 'a', '.', '.', '.', '.', '.', '.', '.']
# ['n', 'a', 'ŋ', 'k', 'a', '.', '.', '.', '.', '.', '.']
# ['j', 'oː', 'k', 'a', '.', '.', '.', '.', '.', '.', '.']
# ['k̒', 'u', 'ŋ', 'k', 'a', '.', '.', '.', '.', '.', '.']
# ['t̒', 'uː', 'k', 'a', '.', '.', '.', '.', '.', '.', '.']
# ['h', 'a', 't', 'z', 'ï', 'k', 'a', '.', '.', '.', '.']
# ['t̓', 'ïː', 't', 'z', 'ï', '.', '.', '.', '.', '.', '.']
# ['-1', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['t̓', 'aː', 't', 'z', 'ï', '.', '.', '.', '.', '.', '.']
# ['-1', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['m', 'iː', 't', 'z', 'ï', '.', '.', '.', '.', '.', '.']
# ['-1', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['j', 'uː', 't', 'z', 'ï', '.', '.', '.', '.', '.', '.']
# ['-1', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['ʔ', 'i', 't', 'z', 'ï', 't', 'z', 'ï', '.', '.', '.']
# ['-1', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['m', 'uː', 't', 'z', 'ï', '.', '.', '.', '.', '.', '.']
# ['-1', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['n', 'a', 'n', 'a', 't', 'z', 'ï', '.', '.', '.', '.']
# ['-1', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['j', 'aː', 't', 'z', 'ï', '.', '.', '.', '.', '.', '.']
# ['-1', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['k̒', 'u', 'w', 'u', 'n', 'u', 't', 'z', 'ï', '.', '.']
# ['-1', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['t̒', 'u', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['-1', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['N', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['ʤ', 'uː', 'i', 't', 'ʒ', 'i', '.', '.', '.', '.', '.']
# ['ʤ', 'uː', 'n', 'i', '.', '.', '.', '.', '.', '.', '.']
# ['ʤ', 'uː', 's', 'a', 'ŋ', '.', '.', '.', '.', '.', '.']
# ['n', 'i', 'ʤ', 'u', '.', '.', '.', '.', '.', '.', '.']
# ['s', 'a', 'n', 'ʤ', 'u', '.', '.', '.', '.', '.', '.']
# ['ʃ', 'i', 'ʤ', 'u', '.', '.', '.', '.', '.', '.', '.']
# ['g', 'o', 'ʤ', 'u', '.', '.', '.', '.', '.', '.', '.']
# ['r', 'o', 'k', 'u', 'ʤ', 'u', '.', '.', '.', '.', '.']
# ['n', 'a', 'n', 'a', 'ʤ', 'u', '.', '.', '.', '.', '.']
# ['h', 'a', 't', 'ʒ', 'i', 'ʤ', 'u', '.', '.', '.', '.']
# ['k̒', 'j', 'uː', 'ʤ', 'u', '.', '.', '.', '.', '.', '.']
# ['ç', 'a', 'k', 'u', '.', '.', '.', '.', '.', '.', '.']
# ['s', 'e', 'ŋ', '.', '.', '.', '.', '.', '.', '.', '.']
# ['n', 'i', 'ʤ', 'u', '.', '.', '.', '.', '.', '.', '.']
# ['ʃ', 'i', 'ʤ', 'u', 'k', 'u', '.', '.', '.', '.', '.']
# ['t', 'ʒ', 'uː', 'r', 'i', '.', '.', '.', '.', '.', '.']
# ['t̓', 'aː', 'r', 'i', '.', '.', '.', '.', '.', '.', '.']
# ['m', 'i', 'ʧ', 'a', 'r', 'i', '.', '.', '.', '.', '.']
# ['j', 'o', 't', 'a', 'r', 'i', '.', '.', '.', '.', '.']
# ['g', 'o', 'n', 'i', 'ŋ', '.', '.', '.', '.', '.', '.']
# ['r', 'o', 'k', 'u', 'n', 'i', 'ŋ', '.', '.', '.', '.']
# ['ʃ', 'i', 't', 'ʒ', 'i', 'n', 'i', 'ŋ', '.', '.', '.']
# ['h', 'a', 't', 'ʒ', 'i', 'n', 'i', 'ŋ', '.', '.', '.']
# ['k̓', 'u', 'n', 'i', 'ŋ', '.', '.', '.', '.', '.', '.']
# ['ʤ', 'uː', 'n', 'i', 'ŋ', '.', '.', '.', '.', '.', '.']
# ['t', 'ʒ', 'o', 'k', 'ëː', 'r', 'i', '.', '.', '.', '.']
# ['t̓', 'a', 'k', 'ëː', 'r', 'i', '.', '.', '.', '.', '.']
# ['m', 'i', 'k', 'ëː', 'r', 'i', '.', '.', '.', '.', '.']
# ['j', 'u', 'k', 'ëː', 'r', 'i', '.', '.', '.', '.', '.']
# ['ʔ', 'i', 't', 'z', 'ï', 'k', 'ëː', 'r', 'i', '.', '.']
# ['m', 'u', 'k', 'ëː', 'r', 'i', '.', '.', '.', '.', '.']
# ['n', 'a', 'n', 'a', 'k', 'ëː', 'r', 'i', '.', '.', '.']
# ['j', 'a', 'k', 'ëː', 'r', 'i', '.', '.', '.', '.', '.']
# ['k̓', 'u', 'ŋ', 'k', 'ëː', 'r', 'i', '.', '.', '.', '.']
# ['t̒', 'u', 'k', 'ëː', 'r', 'i', '.', '.', '.', '.', '.']
# ['h', 'a', 'm', 'b', 'u', 'ŋ', '.', '.', '.', '.', '.']
# ['h', 'a', 'm', 'b', 'u', 'ŋ', '.', '.', '.', '.', '.']
# ['ʔ', 'i', 'p', 'p', 'ai', '.', '.', '.', '.', '.', '.']
# ['ʔn', 'aː', 'r', 'i', '.', '.', '.', '.', '.', '.', '.']
# ['m', 'i', 'ɸ', 'a', 'r', 'e', '.', '.', '.', '.', '.']
# ['j', 'o', 'ɸ', 'a', 'r', 'e', '.', '.', '.', '.', '.']
# ['m', 'a', 'n', 'd', 'ï', '.', '.', '.', '.', '.', '.']

# %%
symbols=["{}音".format(i+1) for i in range(maxlength)]
print(symbols)
# Out:
# ['1音', '2音', '3音', '4音', '5音', '6音', '7音', '8音', '9音', '10音', '11音']

# %%
splitOninDf=pd.DataFrame(splitOnin,index=list(range(len(oninDf))),columns=symbols)

# %%
newOninDf=pd.concat([oninDf["音韻表記１"], splitOninDf], axis=1)

# %%
newOninDf
# Out:
#                     音韻表記１  1音  2音  3音  4音  5音  6音  7音 8音 9音 10音 11音
# 0                    mïzï   m   ï   z   ï   .   .   .  .  .   .   .
# 1                      ju   j   u   .   .   .   .   .  .  .   .   .
# 2                ʔatzïk̓ë   ʔ   a   t   z   ï  k̓   ë  .  .   .   .
# 3                      ʧa   ʧ   a   .   .   .   .   .  .  .   .   .
# 4                      NR  -1   .   .   .   .   .   .  .  .   .   .
# 5                   hammë   h   a   m   m   ë   .   .  .  .   .   .
# 6                    miʃi   m   i   ʃ   i   .   .   .  .  .   .   .
# 7                    ʃiru   ʃ   i   r   u   .   .   .  .  .   .   .
# 8               k̒at̒ïmuŋ  k̒   a  t̒   ï   m   u   ŋ  .  .   .   .
# 9                     kai   k  ai   .   .   .   .   .  .  .   .   .
# 10                   ʔuʃu   ʔ   u   ʃ   u   .   .   .  .  .   .   .
# 11                   ʃoːi   ʃ  oː   i   .   .   .   .  .  .   .   .
# 12                   misu   m   i   s   u   .   .   .  .  .   .   .
# 13                     sï   s   ï   .   .   .   .   .  .  .   .   .
# 14                  k̒oʃo  k̒   o   ʃ   o   .   .   .  .  .   .   .
# 15                 ʔabura   ʔ   a   b   u   r   a   .  .  .   .   .
# 16   ʃiru zata/k̓uru zata  -1   .   .   .   .   .   .  .  .   .   .
# 17                 k̓waʃi  k̓   w   a   ʃ   i   .   .  .  .   .   .
# 18                   k̒uː  k̒  uː   .   .   .   .   .  .  .   .   .
# 19                      3  -1   .   .   .   .   .   .  .  .   .   .
# 20                ʔasabaŋ   ʔ   a   s   a   b   a   ŋ  .  .   .   .
# 21               çimmabaŋ   ç   i   m   m   a   b   a  ŋ  .   .   .
# 22                 juːbaŋ   j  uː   b   a   ŋ   .   .  .  .   .   .
# 23                     NR  -1   .   .   .   .   .   .  .  .   .   .
# 24                     NR  -1   .   .   .   .   .   .  .  .   .   .
# 25                miːʃari   m  iː   ʃ   a   r   i   .  .  .   .   .
# 26               t̒abak̓u  t̒   a   b   a  k̓   u   .  .  .   .   .
# 27                k̓iʃiri  k̓   i   ʃ   i   r   i   .  .  .   .   .
# 28                     NR  -1   .   .   .   .   .   .  .  .   .   .
# 29                     ja   j   a   .   .   .   .   .  .  .   .   .
# ..                    ...  ..  ..  ..  ..  ..  ..  .. .. ..  ..  ..
# 316                   seŋ   s   e   ŋ   .   .   .   .  .  .   .   .
# 317                  niʤu   n   i   ʤ   u   .   .   .  .  .   .   .
# 318                ʃiʤuku   ʃ   i   ʤ   u   k   u   .  .  .   .   .
# 319                tʒuːri   t   ʒ  uː   r   i   .   .  .  .   .   .
# 320                t̓aːri  t̓  aː   r   i   .   .   .  .  .   .   .
# 321                miʧari   m   i   ʧ   a   r   i   .  .  .   .   .
# 322                jotari   j   o   t   a   r   i   .  .  .   .   .
# 323                 goniŋ   g   o   n   i   ŋ   .   .  .  .   .   .
# 324               rokuniŋ   r   o   k   u   n   i   ŋ  .  .   .   .
# 325              ʃitʒiniŋ   ʃ   i   t   ʒ   i   n   i  ŋ  .   .   .
# 326              hatʒiniŋ   h   a   t   ʒ   i   n   i  ŋ  .   .   .
# 327                k̓uniŋ  k̓   u   n   i   ŋ   .   .  .  .   .   .
# 328                ʤuːniŋ   ʤ  uː   n   i   ŋ   .   .  .  .   .   .
# 329              tʒokëːri   t   ʒ   o   k  ëː   r   i  .  .   .   .
# 330              t̓akëːri  t̓   a   k  ëː   r   i   .  .  .   .   .
# 331               mikëːri   m   i   k  ëː   r   i   .  .  .   .   .
# 332               jukëːri   j   u   k  ëː   r   i   .  .  .   .   .
# 333            ʔitzïkëːri   ʔ   i   t   z   ï   k  ëː  r  i   .   .
# 334               mukëːri   m   u   k  ëː   r   i   .  .  .   .   .
# 335             nanakëːri   n   a   n   a   k  ëː   r  i  .   .   .
# 336               jakëːri   j   a   k  ëː   r   i   .  .  .   .   .
# 337             k̓uŋkëːri  k̓   u   ŋ   k  ëː   r   i  .  .   .   .
# 338              t̒ukëːri  t̒   u   k  ëː   r   i   .  .  .   .   .
# 339                hambuŋ   h   a   m   b   u   ŋ   .  .  .   .   .
# 340                hambuŋ   h   a   m   b   u   ŋ   .  .  .   .   .
# 341                ʔippai   ʔ   i   p   p  ai   .   .  .  .   .   .
# 342                ʔnaːri  ʔn  aː   r   i   .   .   .  .  .   .   .
# 343                miɸare   m   i   ɸ   a   r   e   .  .  .   .   .
# 344                joɸare   j   o   ɸ   a   r   e   .  .  .   .   .
# 345                 mandï   m   a   n   d   ï   .   .  .  .   .   .
#
# [346 rows x 12 columns]

# %%
wfonin=basepath.format("単語分解-奄美国直.xlsx")
with pd.ExcelWriter(wfonin, engine='openpyxl') as writer:
    newOninDf.to_excel(writer,sheet_name="Sheet1")

# %%
wfIPA=basepath.format("IPA対応表.xlsx")
with pd.ExcelWriter(wfIPA, engine='openpyxl') as writer:
    cnstsDf.to_excel(writer,sheet_name="子音(consonants)")
    vwsDf.to_excel(writer,sheet_name="母音(vowels)")
